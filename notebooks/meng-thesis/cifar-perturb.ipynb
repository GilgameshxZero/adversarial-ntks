# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("../../")

from adversarial_ntks import dataset
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
CIFAR_TEST = dataset.get_np_data(
    name="cifar10",
    split="test[:100]",
    flatten=False,
)
print(CIFAR_TEST.xs.shape)
# Out:
# (100, 32, 32, 3)

# %%
def plot_xs(xs):
    dataset.plot_images(
        CIFAR_TEST.replace_xs(xs.clip(0, 1)),
        channels=3, flat=False
    )

# %%
plot_xs(CIFAR_TEST.xs)
# Out:
# [7 0 6 9 5 1 7 0 3 2]

# %%
print(0)
xs = CIFAR_TEST.xs.copy()
plot_xs(xs)

add = 2
for _ in range(8):
    print(add)
    xs = CIFAR_TEST.xs.copy()
    xs[:, :, :16, :] -= add / 255.0
    plot_xs(xs)
    add *= 2
# Out:
# 0
# [7 0 6 9 5 1 7 0 3 2]
# 2
# [7 0 6 9 5 1 7 0 3 2]
# 4
# [7 0 6 9 5 1 7 0 3 2]
# 8
# [7 0 6 9 5 1 7 0 3 2]
# 16
# [7 0 6 9 5 1 7 0 3 2]
# 32
# [7 0 6 9 5 1 7 0 3 2]
# 64
# [7 0 6 9 5 1 7 0 3 2]
# 128
# [7 0 6 9 5 1 7 0 3 2]
# 256
# [7 0 6 9 5 1 7 0 3 2]

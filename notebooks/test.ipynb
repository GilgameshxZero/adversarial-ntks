# %%
import tensorflow_datasets as tfds

# %%
data_builder = tfds.builder("cifar10")
data_builder.info
# Out:
# tfds.core.DatasetInfo(
#     name='cifar10',
#     full_name='cifar10/3.0.2',
#     description="""
#     The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#     """,
#     homepage='https://www.cs.toronto.edu/~kriz/cifar.html',
#     data_path='C:\\Users\\0\\tensorflow_datasets\\cifar10\\3.0.2',
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     splits={
#     },
#     citation="""@TECHREPORT{Krizhevsky09learningmultiple,
#         author = {Alex Krizhevsky},
#         title = {Learning multiple layers of features from tiny images},
#         institution = {},
#         year = {2009}
#     }""",
# ...

# %%
tfds.load(name="cifar10", split="train[:1]")
# Out:
# ]
# Generating train examples...: 44556 examples [01:09, 740.69 examples/s]
# Generating train examples...: 44632 examples [01:09, 735.75 examples/s]
# Generating train examples...: 44720 examples [01:09, 776.83 examples/s]
# Generating train examples...: 44805 examples [01:09, 797.99 examples/s]
# Generating train examples...: 44894 examples [01:10, 822.40 examples/s]
# Generating train examples...: 44977 examples [01:10, 817.43 examples/s]
# Generating train examples...: 45060 examples [01:10, 818.80 examples/s]
# Generating train examples...: 45143 examples [01:10, 819.69 examples/s]
# Generating train examples...: 45226 examples [01:10, 768.18 examples/s]
# Generating train examples...: 45304 examples [01:10, 769.26 examples/s]
# Generating train examples...: 45390 examples [01:10, 793.14 examples/s]
# Generating train examples...: 45478 examples [01:10, 817.57 examples/s]
# Generating train examples...: 45564 examples [01:10, 830.01 examples/s]
# ...
